# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
book_df = pd.read_csv('cleaned_book.csv')
book_df
# Out:
#              id                                               name   price  \
# 0      75953557                                 Tâm Lý Học Về Tiền  110000
# 1      57325187  Sách Người Giàu Có Nhất Thành Babylon (Tái Bản...   65660
# 2      76013378  Storytelling With Data - Kể Chuyện Thông Qua D...  213000
# 3      54266567               Sách Nghĩ Giàu Và Làm Giàu (Bìa Mềm)   73000
# 4     206840682      Quyền Lực Của Địa Lý - The Power Of Geography  177000
# ...         ...                                                ...     ...
# 3825   77057263     Combo 2 cuốn Ultrarunning + Tập chạy không khó  321000
# 3826   77058612  Combo 3 cuốn Giải phẫu học về giãn cơ + Ăn và ...  423750
# 3827  203982758                          Bóng Đá - Lối Sống Brazil  255000
# 3828  136599882  Sách Siêu Trí Tuệ - Khả Năng Sinh Tồn Và Thử T...   67500
# 3829  194845996      GIẤC MƠ VÀNG – THBooks – NXB Hà Nội (Bìa mềm)   50000
#
#       original_price  discount  discount_rate  rating_average  review_count  \
# 0             189000     79000             42             4.8          3365
# 1              98000     32340             33             4.8           330
# 2             319000    106000             33             5.0          1773
# 3             110000     37000             34             4.8          1675
# 4             280000    103000             37             5.0           255
# ...              ...       ...            ...             ...           ...
# 3825          321000         0              0             0.0             0
# 3826          423750         0              0             0.0             0
# 3827          300000     45000             15             4.0             1
# 3828           67500         0              0             0.0             0
# 3829           50000         0              0             0.0             0
#
#                                       short_description  \
# 0     Tiền bạc có ở khắp mọi nơi, nó ảnh hưởng đến t...
# 1     NGƯỜI GIÀU CÓ NHẤT THÀNH BABYLONNgười giàu có ...
# 2     Ắt hẳn ai trong chúng ta cũng đều đã từng là n...
# 3     "Think and Grow Rich –Nghĩ giàu và Làm giàu là...
# 4     Tim Marshall đã nhận xét rất xác đáng rằng: "C...
# ...                                                 ...
# 3825  Combo 2 cuốn gồm:1. Tập chạy không khóTác giả:...
# 3826  1. Giải phẫu học về giãn cơTác giả: Arnold G. ...
# 3827  Bóng Đá - Lối Sống BrazilBóng đá đến với Brazi...
# 3828      Siêu Trí Tuệ - Khả Năng Sinh Tồn Và Thử Tà...
# 3829  “60 năm, nhiều thế hệ cầu thủ đã qua đi.60 năm...
#
#       all_time_quantity_sold                      authors          categories  \
# 0                      22821            ['Morgan Housel']     Sách tiếng Việt
# 1                       2129     ['GEORGE SAMUEL CLASON']     Sách tiếng Việt
# 2                      10244  ['Cole Nussbaumer Knaflic']     Sách tiếng Việt
# 3                      11623            ['Napoleon Hill']     Sách tiếng Việt
# 4                       2894             ['Tim Marshall']    Sách kinh tế học
# ...                      ...                          ...                 ...
# 3825                       2            ['nhieu tac gia']  Thể Dục - Thể Thao
# 3826                       1            ['nhieu tac gia']  Thể Dục - Thể Thao
# 3827                       1              ['Alex Bellos']  Thể Dục - Thể Thao
# 3828                       1                 ['Lê Quang']                Root
# 3829                       1            ['nhieu tac gia']  Thể Dục - Thể Thao
#
#                publisher_vn book_cover  number_of_page  \
# 0                1980 Books    Bìa mềm             384
# 1     First News - Trí Việt    Bìa gập             216
# 2                   Sunbook    Bìa mềm             280
# 3     First News - Trí Việt    Bìa mềm             450
# 4                   Nhã Nam    Bìa mềm             559
# ...                     ...        ...             ...
# 3825             Pandabooks    Bìa mềm             744
# 3826             Pandabooks    Bìa mềm             688
# 3827          Phoenix Books    Bìa mềm             572
# 3828        Phương Nam Book    Bìa mềm             127
# 3829                THBooks    Bìa mềm             228
#
#                           manufacturer
# 0                 Nhà Xuất Bản Dân Trí
# 1         Nhà Xuất Bản Tổng hợp TP.HCM
# 2                Nhà Xuất Bản Thế Giới
# 3         Nhà Xuất Bản Tổng hợp TP.HCM
# 4                  Nhà Xuất Bản Phụ Nữ
# ...                                ...
# 3825  Nhà Xuất Bản Thể Thao Và Du Lịch
# 3826     Nhà Xuất Bản Thể Dục Thể Thao
# 3827     Nhà Xuất Bản Văn Hóa Văn Nghệ
# 3828               Nhà Xuất Bản Phụ Nữ
# 3829               Nhà Xuất Bản Hà Nội
#
# [3830 rows x 16 columns]

# %% [markdown]
# # SEE HOWMANY PUSHLISHER IN VN, AND THE AFFECT OF ITS TO PRICE

# %%
label_counts = book_df['publisher_vn'].value_counts()

# Create a bar plot of label counts
label_counts[:10].plot.bar()

# Add labels and title
plt.xlabel('publisher_vn')
plt.ylabel('Count')
plt.title('Count of Labels')

# Display the plot
plt.show()

# %%
label_counts = book_df['publisher_vn'].value_counts()

# Select the top 10 labels based on their counts
top_10_labels = label_counts.head(10).index

# Filter the DataFrame to include only rows with the top 10 labels
filtered_df = book_df[book_df['publisher_vn'].isin(top_10_labels)]

# Create a box plot for the top 10 labels versus the numerical column
filtered_df.boxplot(column='original_price', by='publisher_vn', figsize=(10, 6))

# Set labels and title
plt.xlabel('publisher_vn')
plt.ylabel('original_price')

# Rotate x-axis labels if needed
plt.xticks(rotation=45)

# Display the plot
plt.show()

# %% [markdown]
# # SEE HOWMANY CATEGORIES  , AND THE AFFECT OF ITS TO PRICE

# %%
label_counts = book_df['categories'].value_counts()

# Create a bar plot of label counts
label_counts[:10].plot.bar()

# Add labels and title
plt.xlabel('categories')
plt.ylabel('Count')
plt.title('Count of Labels')

# Display the plot
plt.show()

# %%
print(len(book_df['categories'].unique()))
print(book_df['categories'].unique())
book_df[:10].boxplot(column='original_price', by='categories', figsize=(8, 6))

# Set plot labels and title
plt.xlabel('categories')
plt.ylabel('original_price')
plt.xticks(rotation=90)

# Display the plot
plt.show()
# Out:
# 82
# ['Sách tiếng Việt' 'Sách kinh tế học' 'Sách kỹ năng làm việc'
#  'Sách tài chính, tiền tệ' 'Bài học kinh doanh' 'Sách khởi nghiệp'
#  'Sách Marketing - Bán hàng ' 'Sách doanh nhân' 'Root'
#  'Sách quản trị, lãnh đạo' 'Sách quản trị nhân lực'
#  'Sách tài chính, kế toán' 'Kiến thức - Bách khoa' 'Văn học thiếu nhi'
#  'Truyện tranh Ehon' 'Truyện tranh thiếu nhi' 'Truyện kể cho bé'
#  'Đạo đức - Kỹ năng sống' 'Truyện cổ tích' 'Tô màu - Luyện chữ  '
#  'Sách tư duy - Kỹ năng sống' 'Nhà Sách Tiki' 'Sách nghệ thuật sống đẹp'
#  'Sách hướng nghiệp - Kỹ năng mềm' 'Sách Làm Cha Mẹ'
#  'Sách Dinh Dưỡng - Sức Khỏe Cho Bé' 'Sách Kiến Thức - Kỹ Năng Cho Trẻ'
#  'Sách Thai Giáo' 'Sách giáo dục' 'Sách Giáo Khoa Cấp 2'
#  'Giáo Trình Đại Học - Cao Đẳng' 'Sách Giáo Khoa Cấp 1'
#  'Sách Giáo Khoa Cấp 3' 'Sách Học Tiếng Anh' 'Sách Học Tiếng Hoa'
#  'Sách Học Tiếng Hàn' 'Ngoại Ngữ Khác' 'Sách Học Tiếng Nhật'
#  'Sách Luyện Thi Đại Học - Cao Đẳng' 'Sách tham khảo cấp II'
#  'Sách tham khảo cấp III' 'Sách tham khảo cấp I' 'Sách chuyên đề'
#  'Từ Điển Tiếng Trung' 'Từ Điển Tiếng Anh' 'Từ Điển Tiếng Việt'
#  'Từ Điển Tiếng Nhật' 'Từ Điển Ngôn Ngữ Khác' 'Từ Điển Tiếng Hàn'
#  'Lĩnh vực khác' 'Sách Chiêm Tinh - Horoscope' 'Kiến Thức Bách Khoa'
#  'Triết Học' 'Sách Phong Thủy - Kinh Dịch' 'Sách Khoa Học - Kỹ Thuật'
#  'Lịch Sử Thế Giới' 'Lịch Sử Việt Nam' 'Sách Tô Màu Dành Cho Người Lớn'
#  'Mỹ Thuật - Kiến Trúc' 'Âm Nhạc - Điện Ảnh' 'Truyện Tranh, Manga, Comic'
#  'Tranh Truyện' 'Sách Tôn Giáo - Tâm Linh' '11.11 Campaign'
#  'Sách Địa Danh - Du Lịch' 'Sách Phong Tục - Tập Quán' 'Sách Danh Nhân'
#  'Lý Luận Chính Trị' 'Luật - Văn Bản Luật' 'Sách Nông - Lâm - Ngư Nghiệp'
#  'Tin Học Văn Phòng' 'Lập Trình' 'Thiết Kế - Đồ Họa' 'Sách Y Học'
#  'Tạp Chí - Catalogue' 'Sách Hôn Nhân - Giới Tính' 'Sách Tâm Lý Tuổi Teen'
#  'Chăm sóc sức khỏe' 'Sách Nấu ăn' 'Sách Làm Đẹp'
#  'May - Thêu - Thời Trang' 'Thể Dục - Thể Thao']

# %% [markdown]
# # SEE HOWMANY BOOK COVER  , AND THE AFFECT OF ITS TO PRICE

# %%
label_counts = book_df['book_cover'].value_counts()

# Create a bar plot of label counts
label_counts.plot.bar()

# Add labels and title
plt.xlabel('book_cover')
plt.ylabel('Count')
plt.title('Count of Labels')

# Display the plot
plt.show()

# %%
print(len(book_df['book_cover'].unique()))
print(book_df['book_cover'].unique())
book_df.boxplot(column='original_price', by='book_cover', figsize=(8, 6))

# Set plot labels and title
plt.xlabel('book_cover')
plt.ylabel('original_price')

# Display the plot
plt.show()
# Out:
# 7
# ['Bìa mềm' 'Bìa gập' 'Bìa cứng' 'Bìa rời' 'Paperback' 'Box' 'Bìa Da']

# %% [markdown]
# # AFFECT OF N_PAGE  TO PRICE

# %%
correlation_coefficient = book_df['number_of_page'].corr(book_df['original_price'])

print(correlation_coefficient)
# Out:
# 0.5425250296811849

# %%
book_df[book_df['number_of_page']>=1000]
# Out:
#              id                                               name   price  \
# 1014  119532596  Combo 2 cuốn Giáo Trình Triết Học Mác – Lênin ...  219000
# 1287  108913922  Combo Định hướng bồi dưỡng học sinh năng khiếu...  450000
# 1889  221255330                           Nghệ Thuật Thiết Kế Game  397000
#
#       original_price  discount  discount_rate  rating_average  review_count  \
# 1014          219000         0              0             4.6            27
# 1287          450000         0              0             5.0             3
# 1889          499000    102000             20             0.0             0
#
#                                       short_description  \
# 1014  Bộ giáo trình lý luận chính trị gồm 5 cuốn dàn...
# 1287  Định hướng bồi dưỡng học sinh năng khiếu Toán/...
# 1889  Nghệ Thuật Thiết Kế GameThiết lập tiêu chuẩn t...
#
#       all_time_quantity_sold                     authors  \
# 1014                      67  ['Bộ Giáo Dục Và Đào Tạo']
# 1287                      22             ['Lê Anh Vinh']
# 1889                       1            ['Jesse Schell']
#
#                          categories  \
# 1014  Giáo Trình Đại Học - Cao Đẳng
# 1287         Sách tham khảo cấp III
# 1889       Sách Khoa Học - Kỹ Thuật
#
#                                         publisher_vn book_cover  \
# 1014         Nhà Xuất Bản Chính Trị Quốc Gia Sự Thật    Bìa mềm
# 1287  Công ty TNHH Văn hóa Truyền thông IMO Việt Nam    Bìa mềm
# 1889                                     Alpha Books    Bìa mềm
#
#       number_of_page                             manufacturer
# 1014            1000  Nhà Xuất Bản Chính Trị Quốc Gia Sự Thật
# 1287            1000              nxb dai hoc quoc gia ha noi
# 1889            1000                     Nhà Xuất Bản Dân Trí

# %%
ax = book_df.plot.scatter(x='number_of_page', y='original_price')
ax.set_xlabel('number_of_page')
ax.set_ylabel('original_price')
#ax.set_xticklabels([])
#ax.set_yticklabels([])
# Display the plot
plt.show()

# %% [markdown]
# # SEE HOWMANY MANUFACTURER IN VN, AND THE AFFECT OF ITS TO PRICE

# %%
label_counts = book_df['manufacturer'].value_counts()

# Create a bar plot of label counts
label_counts[:10].plot.bar()

# Add labels and title
plt.xlabel('manufacturer')
plt.ylabel('Count')
plt.title('Count of Labels')

# Display the plot
plt.show()

# %%
print(len(book_df['manufacturer'].unique()))
print(book_df['manufacturer'].unique())
book_df.boxplot(column='original_price', by='manufacturer', figsize=(8, 6))

# Set plot labels and title
plt.xlabel('manufacturer')
plt.ylabel('original_price')

# Display the plot
plt.show()
# Out:
# 92
# ['Nhà Xuất Bản Dân Trí' 'Nhà Xuất Bản Tổng hợp TP.HCM'
#  'Nhà Xuất Bản Thế Giới' 'Nhà Xuất Bản Phụ Nữ' 'Nhà Xuất Bản Lao Động'
#  'Nhà Xuất Bản Đà Nẵng' 'Nhà Xuất Bản Thanh Niên'
#  'Nhà Xuất Bản Công Thương' 'Nhà Xuất Bản Thanh Hóa' 'NXB Trẻ'
#  'Nhà Xuất Bản Kinh Tế TPHCM' 'Nhà Xuất Bản Hồng Đức'
#  'Nhà Xuất Bản Tài Chính' 'NXB Dân Trí' 'Nhà Xuất Bản ĐH Kinh Tế Quốc dân'
#  'Nhà Xuất Bản Hà Nội' 'Nhà Xuất Bản Khoa học và Kỹ thuật'
#  'Nhà Xuất Bản Phụ Nữ Việt Nam' 'Nhà Xuất Bản Lao Động Xã Hội'
#  'Nhà Xuất Bản Đại Học Kinh Tế Quốc Dân' 'The Ivy Press'
#  'Nhà Xuất Bản Văn Học' 'Nhà Xuất Bản Thể Thao Và Du Lịch'
#  'Nhà Xuất Bản Hội Nhà Văn' 'Nhà Xuất Bản Kim Đồng'
#  'Nhà Xuất Bản Đại Học Sư Phạm' 'Nhà Xuất Bản Lao Động - Xã Hội'
#  'nxb thanh nien' 'Nhà Xuất Bản Mỹ Thuật' 'Tiki Tổng Hợp'
#  'Nhà Xuất Bản Đại Học Quốc Gia Hà Nội' 'Hoa Học Trò'
#  'Nhà Xuất Bản Văn Hóa - Văn Nghệ TP.HCM' 'Nhà Xuất Bản Tri Thức'
#  'Nhà Xuất Bản Văn Hóa Văn Nghệ' 'Nhà Xuất Bản Đại Học Quốc Gia TP.HCM'
#  'Nhà Xuất Bản Khoa Học Xã Hội' 'Nhà Xuất Bản Văn Hóa - Văn Nghệ'
#  'nxb lao dong xa hoi' 'Nhà Xuất Bản Tổng Hợp'
#  'Nhà Xuất Bản Giáo Dục Việt Nam'
#  'Nhà Xuất Bản Chính Trị Quốc Gia Sự Thật' 'Nhà Xuất Bản Xây Dựng'
#  'nxb khoa hoc xa hoi' 'Nhà Xuất Bản Giáo Dục'
#  'Nhà Xuất Bản Bách Khoa Hà Nội' 'Nhà Xuất Bản Thông Tin Và Truyền Thông'
#  'Đang cập nhật' 'NXB Tổng Hợp Thành Phố Hồ Chí Minh' 'Thanh Hoá'
#  'dai hoc quoc gia ha noi' 'hong duc' 'Bloomburry Publishing'
#  'Dan Tri Publishing' 'Cambridge University Press'
#  'Nhà Xuất Bản Compass Publishing' 'á châu'
#  'Nhà Xuất Bản Đại Học Sư Phạm TPHCM' 'nxb dai hoc quoc gia ha noi'
#  'ĐHQG Hà Nội' 'Nhà Xuất Bản Lao Động Hà Nội' 'Nhà Xuất Bản Đồng Nai'
#  'Nhà Xuất Bản Văn Hoá Thông Tin' 'Nhà Xuất Bản Hải Phòng'
#  'Nhà Xuất Bản Hồng Bàng' 'Nhà Xuất Bản Từ Điển Bách Khoa'
#  'nxb khoa hoc va ky thuat' 'Nhà Xuất Bản Tôn Giáo'
#  'Nhà Xuất Bản Phương Đông' 'Nhà Xuất Bản Công An Nhân Dân'
#  '"Stewart, Tabori and Chang"' 'Nhà Xuất Bản Chính Trị Quốc Gia'
#  'Nhiều Nhà Xuất Bản' 'Nhà Xuất Bản Thời Đại'
#  'Nhà Xuất Bản Văn Hoá Dân Tộc' 'Nhà Xuất Bản Tổng hợp Đà Nẵng' 'Không có'
#  'Nhà Xuất Bản Giao Thông Vận Tải' 'Nhà Xuất Bản Tư Pháp'
#  'Nhà Xuất Bản Thông Tấn' 'Nhà Xuất Bản Đại Học Huế'
#  'Nhà Xuất Bản Giáo Dục Miền Nam' 'Nhà Xuất Bản Y học' 'Forbes Việt Nam'
#  'Hội Toán Học Việt Nam' 'Saigon Times Group' 'Tạp chí Pi'
#  'Hội Liên Lạc Với Người Việt Nam ở Nước ngoài'
#  'Công ty TNHH Không Gian Sống Media'
#  'Công Ty Cổ Phần Đầu Tư và Phát Hành Sách Hà Nội'
#  'Nhà Xuất Bản Thể Dục  - Thể Thao' 'Nhà Xuất Bản Thể Dục Thể Thao']
